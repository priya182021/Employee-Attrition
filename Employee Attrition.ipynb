# %%
import pandas as pd
df=pd.read_csv('employee.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df["Department"].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df["EducationField"].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
# lets check descriptive statistics for numerical columns
df.describe().style.background_gradient(cmap = 'copper')
# Out:
# <style type="text/css">
# #T_41cdc_row0_col0, #T_41cdc_row0_col2, #T_41cdc_row0_col3, #T_41cdc_row0_col4, #T_41cdc_row0_col6, #T_41cdc_row0_col7, #T_41cdc_row0_col8, #T_41cdc_row0_col9, #T_41cdc_row0_col10, #T_41cdc_row0_col13, #T_41cdc_row0_col14, #T_41cdc_row0_col15, #T_41cdc_row0_col16, #T_41cdc_row0_col17, #T_41cdc_row0_col18, #T_41cdc_row0_col19, #T_41cdc_row0_col20, #T_41cdc_row0_col21, #T_41cdc_row0_col22, #T_41cdc_row0_col23, #T_41cdc_row0_col24, #T_41cdc_row0_col25, #T_41cdc_row7_col1, #T_41cdc_row7_col5, #T_41cdc_row7_col11, #T_41cdc_row7_col12 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_41cdc_row0_col1 {
#   background-color: #ffc37c;
#   color: #000000;
# }
# #T_41cdc_row0_col5 {
#   background-color: #e08d5a;
#   color: #f1f1f1;
# }
# #T_41cdc_row0_col11, #T_41cdc_row3_col12, #T_41cdc_row7_col19, #T_41cdc_row7_col22 {
#   background-color: #070503;
#   color: #f1f1f1;
# }
# ...

# %%
# lets visualize the outliers using Box Plot

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15, 4)

plt.subplot(1, 3, 1)
sns.boxplot(df['DailyRate'])

plt.subplot(1, 3, 2)
sns.boxplot(df['MonthlyIncome'])

plt.subplot(1, 3, 3)
sns.boxplot(df['MonthlyRate'])

plt.suptitle('Outliers Present in the Data')
plt.show()
# Out:
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df=df[df["MonthlyIncome"]>17000]

# %%
# lets check descriptive statistics for categorical columns
df.describe(include = 'object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count         97             97                      97             97     97
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq          92             75                      70             39     63
#
#         JobRole MaritalStatus Over18 OverTime
# count        97            97     97       97
# unique        2             3      1        2
# top     Manager       Married      Y       No
# freq         61            53     97       73

# %%
# lets check the Target variable

plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
sns.countplot(df['Attrition'],)

plt.xlabel('Attrit or Not?', fontsize = 10)

plt.subplot(1, 2, 2)
df['Attrition'].value_counts().plot(kind = 'pie', explode = [0, 0.1], autopct = '%.2f%%', startangle = 90,
                                       labels = ['1','0'], shadow = True, pctdistance = 0.5)
plt.axis('off')

plt.suptitle('Target variable', fontsize = 15)
plt.show()
# Out:
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
## Univariate Analysis on Categorical Columns

plt.rcParams['figure.figsize'] = (24,12)

plt.subplot(3, 3, 1)
sns.countplot(df['Attrition'], palette = 'cool')

plt.subplot(3, 3, 2)
sns.countplot(df['BusinessTravel'], palette = 'cool')

plt.subplot(3, 3, 3)
sns.countplot(df['Department'], palette = 'cool')

plt.subplot(3, 3, 4)
sns.countplot(df['EducationField'], palette = 'cool')

plt.subplot(3, 3, 5)
sns.countplot(df['Gender'], palette = 'cool')

plt.subplot(3, 3, 6)
sns.countplot(df['JobRole'], palette = 'cool')

plt.subplot(3, 3, 7)
sns.countplot(df['MaritalStatus'], palette = 'cool')

plt.subplot(3, 3, 8)
sns.countplot(df['Over18'], palette = 'cool')

plt.subplot(3,3,9)
sns.countplot(df['OverTime'],palette = 'cool')

plt.suptitle('Univariate Analysis on Categorical Columns')
plt.show()
# Out:
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
### Lets check the Impact of OverTime and MonthlyIncome on Attrition

plt.rcParams['figure.figsize'] = (15, 12)

plt.subplot(2, 4, 1)
sns.boxplot(df['Attrition'], df['MonthlyIncome'], palette = 'magma')

plt.subplot(2, 4, 2)
sns.boxplot(df['Attrition'], df['PerformanceRating'], palette = 'magma')

plt.subplot(2, 4, 3)
sns.boxplot(df['Attrition'], df['RelationshipSatisfaction'], palette = 'magma')

plt.subplot(2, 4, 4)
sns.boxplot(df['Attrition'], df['TotalWorkingYears'], palette = 'magma')

plt.subplot(2, 4, 5)
sns.boxplot(df['Attrition'], df['TrainingTimesLastYear'], palette = 'magma')

plt.subplot(2, 4, 6)
sns.boxplot(df['Attrition'], df['YearsAtCompany'], palette = 'magma')

plt.subplot(2, 4, 7)
sns.boxplot(df['Attrition'], df['YearsSinceLastPromotion'], palette = 'magma')

plt.subplot(2, 4, 8)
sns.boxplot(df['Attrition'], df['YearsWithCurrManager'], palette = 'magma')

plt.suptitle('Impact of Income on Attrition\n', fontsize = 20)
plt.show()
# Out:
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# # Here we can see emplyees year since last promotion are terminated. so employees waiting for promotion but didnt get so they resign the company

# %%
plt.rcParams['figure.figsize'] = (10, 6)
sns.boxplot(df['Attrition'], df['Age'], palette = 'magma')
# Out:
# C:\Users\D priyanka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='Age'>

# %%
# lets check the distribution of distance undertaken by the employees

plt.rcParams['figure.figsize'] = (17, 4)
sns.countplot(x='DistanceFromHome',hue="Attrition", data=df,palette = 'spring')
plt.xlabel(' ', fontsize = 14)
plt.title('Distribution of distance undertaken by the Employees')
plt.show()

# %%
df=df.drop(["EmployeeCount","StandardHours"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\DPRIYA~1\AppData\Local\Temp/ipykernel_16616/1126227600.py in <module>
# ----> 1 df=df.drop(["EmployeeCount","StandardHours","Over18","EmployeeNumber",],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df=df.drop(["Over18","EmployeeNumber"],axis=1)

# %%
# lets check the Heat Map for the Data with respect to correlation.

plt.rcParams['figure.figsize'] = (20, 12)
sns.heatmap(df.corr(), annot = True, linewidth = 0.5, cmap = 'Wistia')
plt.title('Correlation Heat Map', fontsize = 15)
plt.show()

# %%
#monthly income with job level has high positive correlation.
#Years At Company with years with current manager and years in current role also has high positive correlation which is obvious.
#total working years and age.
#performance Rating and performabce salary hike.
#years at current company and no. of companies worked has high negative correlation.

# %%
## Lets check the categorical columns present in the data
df.select_dtypes('object').head()
# Out:
#     Attrition BusinessTravel              Department    EducationField  \
# 25         No  Travel_Rarely  Research & Development             Other
# 29         No  Travel_Rarely                   Sales         Marketing
# 45        Yes  Travel_Rarely  Research & Development  Technical Degree
# 62         No  Travel_Rarely  Research & Development           Medical
# 105        No     Non-Travel         Human Resources   Human Resources
#
#      Gender            JobRole MaritalStatus OverTime
# 25   Female            Manager      Divorced       No
# 29   Female            Manager        Single       No
# 45   Female  Research Director       Married       No
# 62   Female  Research Director      Divorced      Yes
# 105  Female            Manager       Married       No

# %%
from sklearn.preprocessing import LabelEncoder

d_types = dict(df.dtypes)

for name , type_ in d_types.items():
    if str(type_) == 'object':
        Le = LabelEncoder()
        df[name] = Le.fit_transform(df[name])

df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 25     53          0               2       1282           1                 5
# 29     46          0               2        705           2                 2
# 45     41          1               2       1360           1                12
# 62     50          0               2        989           1                 7
# 105    59          0               0       1420           0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1374   58          0               2        605           2                21
# 1377   49          0               1       1064           1                 2
# 1401   55          0               2        189           0                26
# 1437   39          0               0        105           1                 9
# 1443   42          0               2        300           1                 2
#
# ...

# %%
Y = df['Attrition']
X = df.drop(['Attrition'], axis = 1)

# %%
from sklearn.model_selection import train_test_split

Xtrain , Xtest , Ytrain , Ytest = train_test_split(X , Y , test_size = 0.2 , random_state = 4)

# %%
from sklearn.ensemble import RandomForestClassifier 

model = RandomForestClassifier()
model.fit(Xtrain , Ytrain)
# Out:
# RandomForestClassifier()

# %%
print("Testing Accuracy : " , model.score(Xtest , Ytest))
# Out:
# Testing Accuracy :  0.9

# %%
predictions = model.predict(Xtest)

# %%
from sklearn.metrics import confusion_matrix 

matrix = confusion_matrix(Ytest , predictions)
matrix
# Out:
# array([[18,  0],
#        [ 2,  0]], dtype=int64)
